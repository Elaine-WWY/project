# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics using Python

# %% [markdown]
# ## Assignment: Diagnostic Analysis using Python
#
# This analysis is related to the appointments of National Health Service (NHS)
#
# This jupyter notebook contains the major working procedures of handling the real datasets.
#
#
# ###  GitHub repository (Elaine Wong)
#  > https://ElaineWong-HR/github.io/Wong_Elaine_DA201_Assignment/

# %% [markdown]
# ## Import libraries

# %%
# Import the  libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import plotly.express as px 
import plotly.graph_objects as go
import plotly.offline
import plotly.graph_objs as go
from pyecharts import options as opts
from pyecharts.charts import Sankey

# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## data cleansing

# %% [markdown]
# ### Handle dataset 1: actual_duration

# %%
# Import and sense-check the actual_duration.csv data set as ad.
ad = pd.read_csv('actual_duration.csv')

# View the DataFrame.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# 2        01-Dec-21            6-10 Minutes                   1698
# 3        01-Dec-21  Unknown / Data Quality                   1277
# 4        01-Dec-21           16-20 Minutes                    730

# %%
# Determine the metadata of the data set.
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# Convert the appointment date to datetime type
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])

# Determine the record period of ad dataframe
ad['appointment_date'].agg(['min','max'])
# Out:
# min   2021-12-01
# max   2022-06-30
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Create some additional columns of dates in ad DataFrame

month_dict={1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May',6:'Jun',
            7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}

season_dict={1:'Winter',2:'Winter',3:'Winter',
             4:'Spring',5:'Spring',6:'Spring',
             7:'Summer',8:'Summer',9:'Summer',
             10:'Autumn',11:'Autumn',12:'Autumn'}

region_dict={'E40000003':'London', 'E40000005':'South East',
             'E40000006':'South West', 'E40000007':'East of England', 
             'E40000010':'North West', 'E40000011':'Midlands', 'E40000012':'North East and Yorkshire'}

ad['appointment_month'] = ad['appointment_date'].dt.to_period('M')
ad['year']=ad['appointment_date'].dt.year
ad['quarter']=ad['appointment_date'].dt.quarter
ad['month'] = ad['appointment_date'].dt.month
ad['month_year']=ad['month'].map(month_dict).astype(str)+'-'+ad.year.astype(str)
ad['season']=ad['month'].map(season_dict)

ad['weekday']=ad['appointment_date'].dt.day_name()

ad['region']=ad['region_ons_code'].map(region_dict)

ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments  \
# 0       2021-12-01           31-60 Minutes                    364
# 1       2021-12-01           21-30 Minutes                    619
# 2       2021-12-01            6-10 Minutes                   1698
# 3       2021-12-01  Unknown / Data Quality                   1277
# 4       2021-12-01           16-20 Minutes                    730
#
#   appointment_month  year  quarter  month month_year  season    weekday  \
# 0           2021-12  2021        4     12   Dec-2021  Autumn  Wednesday
# 1           2021-12  2021        4     12   Dec-2021  Autumn  Wednesday
# 2           2021-12  2021        4     12   Dec-2021  Autumn  Wednesday
# 3           2021-12  2021        4     12   Dec-2021  Autumn  Wednesday
# 4           2021-12  2021        4     12   Dec-2021  Autumn  Wednesday
#
#                      region
# 0  North East and Yorkshire
# 1  North East and Yorkshire
# 2  North East and Yorkshire
# 3  North East and Yorkshire
# 4  North East and Yorkshire

# %%
# Determine the number of unique elements of the data set.
ad.nunique()
# Out:
# sub_icb_location_code         106
# sub_icb_location_ons_code     106
# sub_icb_location_name         106
# icb_ons_code                   42
# region_ons_code                 7
# appointment_date              212
# actual_duration                 7
# count_of_appointments        7611
# appointment_month               7
# year                            2
# quarter                         3
# month                           7
# month_year                      7
# season                          3
# weekday                         7
# region                          7
# dtype: int64

# %%
# Determine whether there are missing values.
ad.isnull().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# appointment_month            0
# year                         0
# quarter                      0
# month                        0
# month_year                   0
# season                       0
# weekday                      0
# region                       0
# dtype: int64

# %%
# Determine whether there are duplicated records.
ad.duplicated().sum()
# Out:
# 0

# %%
ad.describe()
# Out:
#        count_of_appointments           year        quarter          month
# count          137793.000000  137793.000000  137793.000000  137793.000000
# mean             1219.080011    2021.858433       1.848766       4.700507
# std              1546.902956       0.348607       0.988825       3.355861
# min                 1.000000    2021.000000       1.000000       1.000000
# 25%               194.000000    2022.000000       1.000000       2.000000
# 50%               696.000000    2022.000000       2.000000       4.000000
# 75%              1621.000000    2022.000000       2.000000       6.000000
# max             15400.000000    2022.000000       4.000000      12.000000

# %%
# Determine the total actualized appointment in ad dataframe
ad['count_of_appointments'].sum()
# Out:
# 167980692

# %% [markdown]
# ## Handle dataset 2: appointments_regional

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
ar = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Determine the metadata of the data set.
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# Convert the appointment month to datetime type
ar['appointment_month'] = pd.to_datetime(ar['appointment_month'])

# Determine the record period of ad dataframe
ar['appointment_month'].agg(['min','max'])
# Out:
# min   2020-01-01
# max   2022-06-01
# Name: appointment_month, dtype: datetime64[ns]

# %%
# Create some additional columns of dates in ad DataFrame
month_dict={1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May',6:'Jun',
            7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}

season_dict={1:'Winter',2:'Winter',3:'Winter',
             4:'Spring',5:'Spring',6:'Spring',
             7:'Summer',8:'Summer',9:'Summer',
             10:'Autumn',11:'Autumn',12:'Autumn'}

region_dict={'E40000003':'London', 'E40000005':'South East',
             'E40000006':'South West', 'E40000007':'East of England', 
             'E40000010':'North West', 'E40000011':'Midlands', 'E40000012':'North East and Yorkshire'}

ar['year']=ar['appointment_month'].dt.year
ar['quarter']=ar['appointment_month'].dt.quarter
ar['month']= ar['appointment_month'].dt.month
ar['month_year']=ar['month'].map(month_dict).astype(str)+'-'+ar.year.astype(str)
ar['season']=ar['month'].map(season_dict)

code = ad[['icb_ons_code','region_ons_code']].drop_duplicates()
code_dict = dict(zip(code.icb_ons_code,code.region_ons_code))
ar['region_ons_code']=ar['icb_ons_code'].map(code_dict)

region_dict={'E40000003':'London', 'E40000005':'South East',
             'E40000006':'South West', 'E40000007':'East of England', 
             'E40000010':'North West', 'E40000011':'Midlands', 'E40000012':'North East and Yorkshire'}

ar['region']=ar['region_ons_code'].map(region_dict)

ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 1    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 2    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 3    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 4    E54000034        2020-01-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments  year  quarter  \
# 0                             1 Day                   8107  2020        1
# 1                    15  to 21 Days                   6791  2020        1
# 2                       2 to 7 Days                  20686  2020        1
# 3                    22  to 28 Days                   4268  2020        1
# 4                     8  to 14 Days                  11971  2020        1
#
#    month month_year  season region_ons_code      region
# 0      1   Jan-2020  Winter       E40000005  South East
# 1      1   Jan-2020  Winter       E40000005  South East
# 2      1   Jan-2020  Winter       E40000005  South East
# 3      1   Jan-2020  Winter       E40000005  South East
# 4      1   Jan-2020  Winter       E40000005  South East

# %%
# Determine the number of unique elements of the data set.
ar.nunique()
# Out:
# icb_ons_code                            42
# appointment_month                       30
# appointment_status                       3
# hcp_type                                 3
# appointment_mode                         5
# time_between_book_and_appointment        8
# count_of_appointments                22807
# year                                     3
# quarter                                  4
# month                                   12
# month_year                              30
# season                                   4
# region_ons_code                          7
# region                                   7
# dtype: int64

# %%
# Determine whether there are missing values.
ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# year                                 0
# quarter                              0
# month                                0
# month_year                           0
# season                               0
# region_ons_code                      0
# region                               0
# dtype: int64

# %%
# Determine the number of appointment records in ar dataframe
ar['count_of_appointments'].sum()
# Out:
# 742804525

# %%
# Determine the number of duplicated record
ar.duplicated().sum()

# Keep all records since there is no record of every single appointments for cross-check. 
# The total numbers of appointment match with nc dataset.
# Out:
# 21604

# %%
# Determine the descriptive statistics of the data set.
ar.describe()
# Out:
#        count_of_appointments           year        quarter          month
# count          596821.000000  596821.000000  596821.000000  596821.000000
# mean             1244.601857    2020.806061       2.300403       5.903294
# std              5856.887042       0.750589       1.106084       3.414846
# min                 1.000000    2020.000000       1.000000       1.000000
# 25%                 7.000000    2020.000000       1.000000       3.000000
# 50%                47.000000    2021.000000       2.000000       6.000000
# 75%               308.000000    2021.000000       3.000000       9.000000
# max            211265.000000    2022.000000       4.000000      12.000000

# %% [markdown]
# ## Handle dataset 3: national_categories

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
nc = pd.read_excel('national_categories.xlsx')

# View the DataFrame.
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# 2                              Home Visit                     79
# 3              General Consultation Acute                    725
# 4            Structured Medication Review                      2
#
#   appointment_month
# 0           2021-08
# 1           2021-08
# 2           2021-08
# 3           2021-08
# 4           2021-08

# %%
# Determine the number of categories in each variable.
nc.nunique()
# Out:
# appointment_date          334
# icb_ons_code               42
# sub_icb_location_name     106
# service_setting             5
# context_type                3
# national_category          18
# count_of_appointments    9957
# appointment_month          11
# dtype: int64

# %%
# Determine the metadata of the data set.
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Determine whether there are missing values.
nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Convert the appointment date to datetime type
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])

# Determine the record period of ad dataframe
nc['appointment_date'].agg(['min','max'])
# Out:
# min   2021-08-01
# max   2022-06-30
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Create some additional columns of dates in nc DataFrame

month_dict={1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May',6:'Jun',
            7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}

season_dict={1:'Winter',2:'Winter',3:'Winter',
             4:'Spring',5:'Spring',6:'Spring',
             7:'Summer',8:'Summer',9:'Summer',
             10:'Autumn',11:'Autumn',12:'Autumn'}

nc['year']=nc['appointment_date'].dt.year
nc['quarter']=nc['appointment_date'].dt.quarter
nc['month']=nc['appointment_date'].dt.month
nc['month_year']=nc['month'].map(month_dict).astype(str)+'-'+nc.year.astype(str)
nc['season']=nc['month'].map(season_dict)
nc['weekday']=nc['appointment_date'].dt.day_name()

code = ad[['icb_ons_code','region_ons_code']].drop_duplicates()
code_dict = dict(zip(code.icb_ons_code,code.region_ons_code))
nc['region_ons_code']=nc['icb_ons_code'].map(code_dict)


region_dict={'E40000003':'London', 'E40000005':'South East',
             'E40000006':'South West', 'E40000007':'East of England', 
             'E40000010':'North West', 'E40000011':'Midlands', 'E40000012':'North East and Yorkshire'}

nc['region']=nc['region_ons_code'].map(region_dict)

nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# 2                              Home Visit                     79
# 3              General Consultation Acute                    725
# 4            Structured Medication Review                      2
#
#   appointment_month  year  quarter  month month_year  season weekday  \
# 0           2021-08  2021        3      8   Aug-2021  Summer  Monday
# 1           2021-08  2021        3      8   Aug-2021  Summer  Monday
# 2           2021-08  2021        3      8   Aug-2021  Summer  Monday
# 3           2021-08  2021        3      8   Aug-2021  Summer  Monday
# 4           2021-08  2021        3      8   Aug-2021  Summer  Monday
#
#   region_ons_code                    region
# 0       E40000012  North East and Yorkshire
# 1       E40000012  North East and Yorkshire
# 2       E40000012  North East and Yorkshire
# 3       E40000012  North East and Yorkshire
# 4       E40000012  North East and Yorkshire

# %%
# Determine the number of duplicated record
nc.duplicated().sum()
# Out:
# 0

# %%
# Determine the descriptive statistics of the data set.
nc.describe()
# Out:
#        count_of_appointments           year        quarter          month
# count          817394.000000  817394.000000  817394.000000  817394.000000
# mean              362.183684    2021.548196       2.449228       6.456048
# std              1084.576600       0.497672       1.162157       3.596845
# min                 1.000000    2021.000000       1.000000       1.000000
# 25%                 7.000000    2021.000000       1.000000       3.000000
# 50%                25.000000    2022.000000       2.000000       6.000000
# 75%               128.000000    2022.000000       4.000000      10.000000
# max             16590.000000    2022.000000       4.000000      12.000000

# %% [markdown]
# # Investigate staffing issue

# %% [markdown]
# ### Appointment VS Capacity

# %%
# Sum the appointments: by month

# Calculate total appointments per month (Jan 2020 - Jun 2022)
ar_df = ar.groupby(['appointment_month','appointment_status'])['count_of_appointments'].agg('sum').reset_index()

# Calculate the calendars of month
ar_df['daysinmonth'] = ar_df['appointment_month'].apply(lambda t: pd.Period(t, freq='S').days_in_month)

# Calculate the monthly max capacity
ar_df['month_capacity']=1200000*ar_df['daysinmonth']

# Calculate the expected capacity utilisation rate
ar_df['expected_utilisation_rate'] = ar_df['count_of_appointments']/ar_df['month_capacity']*100

# Calculate the actual capacity utilisation for attended appointments
def actual_utilisation(row):
   if row['appointment_status'] == 'Attended':
        return row['count_of_appointments']
ar_df['actual_utilisation'] = ar_df.apply(actual_utilisation, axis=1)
ar_df['actual_utilisation'].fillna(0, inplace=True)

# Calculate the actual capacity utilisation rate
def actual_utilisation_rate(row):
    if row['appointment_status'] == 'Attended':
        return row['expected_utilisation_rate']

ar_df['actual_utilisation_rate'] = ar_df.apply(actual_utilisation_rate, axis=1)
ar_df['actual_utilisation_rate'].fillna(0, inplace=True)

ar_df_line = ar_df.groupby(['appointment_month'])['expected_utilisation_rate','actual_utilisation_rate'].agg('sum').reset_index()
fig = px.line(ar_df_line, x='appointment_month', y=ar_df_line.columns[1:],
              template='none', title='Capacity utilization rate per month',
              labels={'variable':'Utilization Rate',
                      'value': 'Percentage against the maximum capacity',
                     'appointment_month': 'Appointment Month'})
fig.update_xaxes(dtick="M1", tickangle=45)
fig.add_hline(y=100,line_width=3, line_dash="dash", line_color='green', name='Capacity')
fig.update_yaxes(range=[0, 100])
fig.show()
# Out:
# <div>                            <div id="c4fdabc1-2343-45b8-9360-f559b390c78f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4fdabc1-2343-45b8-9360-f559b390c78f")) {                    Plotly.newPlot(                        "c4fdabc1-2343-45b8-9360-f559b390c78f",                        [{"hovertemplate":"Utilization Rate=expected_utilisation_rate<br>Appointment Month=%{x}<br>Percentage against the maximum capacity=%{y}<extra></extra>","legendgroup":"expected_utilisation_rate","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"expected_utilisation_rate","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[73.1163870967742,69.26615229885057,64.65986021505375,44.46633611111111,44.13229032258065,57.47445833333333,60.46085215053764,54.168064516129036,74.2062638888889,76.0804623655914,69.61556111111112,63.268645161290316,60.46255107526881,66.66538392857143,73.18662365591398,66.33314444444444,63.194610215053764,74.40050555555555,69.19144892473119,64.11873924731182,79.22916944444445,81.46191935483873,84.45852777777777,67.5827311827957,68.91256451612902,75.46208333333334,79.55655376344086,66.42516666666667,73.9126559139785,71.74466111111111],"yaxis":"y","type":"scatter"},{"hovertemplate":"Utilization Rate=actual_utilisation_rate<br>Appointment Month=%{x}<br>Percentage against the maximum capacity=%{y}<extra></extra>","legendgroup":"actual_utilisation_rate","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"actual_utilisation_rate","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[65.96314784946237,62.184100574712645,55.69587365591397,38.84117777777778,40.222715053763444,52.619505555555556,55.39486021505377,49.567021505376346,66.63470000000001,68.62708333333333,64.08905277777778,58.04360483870967,55.499241935483866,61.71489583333334,67.98384677419355,61.26781388888889,58.547325268817204,68.93184166666667,63.87365860215054,59.35958333333333,71.54740555555556,73.03899462365592,76.854625,61.43409408602151,63.433322580645154,69.49981845238096,73.03763978494624,60.96892777777778,68.12887365591398,65.87588055555555],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Appointment Month"},"dtick":"M1","tickangle":45},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Percentage against the max ...
#
# var gd = document.getElementById('c4fdabc1-2343-45b8-9360-f559b390c78f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
#Total appointments (ar)

data = ar.groupby(['appointment_month','season'])['count_of_appointments'].agg('sum').reset_index()

fig = px.bar(data, x='appointment_month', y='count_of_appointments', 
             color='season',
             category_orders={'season': ['Spring', 'Summer', 'Autumn', 'Winter']},
             text='count_of_appointments', template='none')
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_layout(title = 'Number of appointments per month', 
                  xaxis_title = "Month", yaxis_title = "Number of Appointments")
fig.show()
# Out:
# <div>                            <div id="756b5876-965e-4062-917a-8631fc0346e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("756b5876-965e-4062-917a-8631fc0346e4")) {                    Plotly.newPlot(                        "756b5876-965e-4062-917a-8631fc0346e4",                        [{"alignmentgroup":"True","hovertemplate":"season=Spring<br>appointment_month=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Spring","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Spring","offsetgroup":"Spring","orientation":"v","showlegend":true,"text":[16007881.0,16417212.0,20690805.0,23879932.0,23508395.0,26784182.0,23913060.0,27495508.0,25828078.0],"textposition":"outside","x":["2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[16007881,16417212,20690805,23879932,23508395,26784182,23913060,27495508,25828078],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"season=Summer<br>appointment_month=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Summer","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":true,"text":[22491437.0,20150520.0,26714255.0,25739219.0,23852171.0,28522501.0],"textposition":"outside","x":["2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00"],"xaxis":"x","y":[22491437,20150520,26714255,25739219,23852171,28522501],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"season=Autumn<br>appointment_month=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Autumn","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Autumn","offsetgroup":"Autumn","orientation":"v","showlegend":true,"text":[28301932.0,25061602.0,23535936.0,30303834.0,30405070.0,25140776.0],"textposition":"outside","x":["2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00"],"xaxis":"x","y":[28301932,25061602,23535936,30303834,30405070,25140776],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"season=Winter<br>appointment_month=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Winter","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Winter","offsetgroup":"Winter","orientation":"v","showlegend":true,"text":[27199296.0,24104621.0,24053468.0,22492069.0,22399569.0,27225424.0,25635474.0,25355260.0,29595038.0],"textposition":"outside","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00"],"xaxis":"x","y":[27199296,24104621,24053468,22492069,22399569,27225424,25635474,25355260,29595038],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Month"},"dtick":"M1","tickangle":45},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Number of Appointments"}},"legend":{"title":{"text":"season"},"tracegroupgap":0},"margin":{"t":60},"barmode":"relative","title":{"text":"Number of appointments per month"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('756b5876-965e-4062-917a-8631fc0346e4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# # Regions

# %%
data = ar.groupby(['appointment_month','region'])['count_of_appointments'].agg('sum').reset_index()

fig = px.line(data, x='appointment_month', y='count_of_appointments',
             template='none', color='region',width=800, height=400)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per month for region', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="897b90a3-48a7-4bfe-8aa2-da23f491ad08" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("897b90a3-48a7-4bfe-8aa2-da23f491ad08")) {                    Plotly.newPlot(                        "897b90a3-48a7-4bfe-8aa2-da23f491ad08",                        [{"hovertemplate":"region=East of England<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"East of England","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East of England","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[3192308,2827790,2865248,1927799,1970358,2452593,2653063,2365588,3104527,3331283,2930557,2756304,2591390,2565219,3116565,2777496,2718326,3078147,2949040,2723599,3297004,3545285,3480448,2901948,2945278,2901798,3405547,2727826,3152914,2973400],"yaxis":"y","type":"scatter"},{"hovertemplate":"region=London<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"London","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"London","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[3736924,3383402,3337073,2211432,2302672,2932005,3223567,2897995,3806970,4012771,3635437,3352777,3210972,3281517,3965147,3523433,3472228,4042266,3871835,3541514,4167503,4316710,4393809,3636396,3768855,3764311,4376534,3534169,4111263,3873375],"yaxis":"y","type":"scatter"},{"hovertemplate":"region=Midlands<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Midlands","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Midlands","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[5326136,4717291,4688218,3111746,3177905,4006573,4 ...

# %%
# 100% stack bar plots

data = ar.groupby(['region','appointment_status'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('region')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='region', y='Percentage',color='appointment_status',
             category_orders={'region': ['Midlands', 'North East and Yorkshire',
                                         'South East', 'London', 'North West',
                                         'East of England','South West']},
                              title="Appointment per region", template='none', text_auto= True)   

fig.show()
# Out:
# <div>                            <div id="df67d947-a350-42b9-85fa-08de4d47cbac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df67d947-a350-42b9-85fa-08de4d47cbac")) {                    Plotly.newPlot(                        "df67d947-a350-42b9-85fa-08de4d47cbac",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["East of England","London","Midlands","North East and Yorkshire","North West","South East","South West"],"xaxis":"x","y":["92.10%","90.67%","91.27%","91.56%","89.93%","91.52%","91.60%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=DNA<br>region=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"DNA","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"DNA","offsetgroup":"DNA","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["East of England","London","Midlands","North East and Yorkshire","North West","South East","South West"],"xaxis":"x","y":["3.28%","5.07%","4.23%","3.59%","5.15%","4.07%","3.67%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Unknown<br>region=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Unknown","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Unknown","offsetgroup":"Unknown","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["East of England","London","Midlands","North East and Yorkshire","North West","South East","South West"],"xaxis":"x","y":["4.62%","4.26%","4.49%","4.85%","4.91%","4.41%","4.73%"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"region"},"categoryorder":"array","categoryarray":["Midlands","North East and Yorkshire","South East","London","North West","East of England","South West"]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Percentage"}},"legend":{"title":{"text":"appointment_status"},"tracegroupgap":0},"title":{"text":"Appointment per region"},"barmode":"relative"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('df67d947-a350-42b9-85fa-08de4d47cbac');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ## HCP types

# %%
data = ar.groupby(['appointment_month','hcp_type'])['count_of_appointments'].agg('sum').reset_index()

fig = px.pie(data, values='count_of_appointments', 
             names='hcp_type', template='none')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_layout(title = 'Appointments by hcp types' ,
                  xaxis_title = "Month", yaxis_title = "Number of Appointments")
fig.show()
# Out:
# <div>                            <div id="36a0bf76-a2da-48bf-9a10-22415212b7f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36a0bf76-a2da-48bf-9a10-22415212b7f9")) {                    Plotly.newPlot(                        "36a0bf76-a2da-48bf-9a10-22415212b7f9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"hcp_type=%{label}<br>count_of_appointments=%{value}<extra></extra>","labels":["GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown","GP","Other Practice staff","Unknown"],"legendgroup":"","name":"","showlegend":true,"values":[14168932,12326031,704333,12467976,11002550,634095,12839993,10498713,714762,8795939,6704003,507939,8924583,6993557,499072,11054065,9047092,589648,11701906,10108127,681404,10481447,9037362,631711,13187253,12660278,866724,13182629,14150521,968782,12501963,11760406,799233,11759814,11021668,754454,11806927,10001104,684038,11827794,9894163,677612,14391125,11973606,860693,12462924,10635500,781508,12334764,10402894,770737,14050148,11866623,867411,13338516,11583564,817139,12299022,10797821,755328,14487785,13126731,907985,14300751,14942504,1060579,14897749,14432800,1074521,12654767,11614470,871539,13138050,11705142,792282,12869711,11688107,797442,15127227,13528583,939228,11908463,11217738,786859,13793934,12823200,878374,12893983,12105677,828418],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"legend":{"tracegroupgap":0},"margin":{"t":60},"xaxis":{"dtick":"M1","tickangle":45,"title":{"text":"Month"}},"title":{"text":"Appointments by hcp types"},"yaxis":{"title":{"text":"Number of Appointments"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('36a0bf76-a2da-48bf-9a10-22415212b7f9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
data = ar.groupby(['appointment_month','hcp_type'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('appointment_month')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_month', y='Percentage',color='hcp_type',
        title='Appointments per hcp type', template='none', text_auto= True)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.show()
# Out:
# <div>                            <div id="6c883103-f545-40a3-97ac-a61693e44281" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c883103-f545-40a3-97ac-a61693e44281")) {                    Plotly.newPlot(                        "6c883103-f545-40a3-97ac-a61693e44281",                        [{"alignmentgroup":"True","hovertemplate":"hcp_type=GP<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"GP","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"GP","offsetgroup":"GP","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["52.09%","51.72%","53.38%","54.95%","54.36%","53.43%","52.03%","52.02%","49.36%","46.58%","49.88%","49.97%","52.49%","52.80%","52.86%","52.19%","52.47%","52.46%","51.82%","51.56%","50.79%","47.19%","49.00%","50.34%","51.25%","50.76%","51.11%","49.80%","50.17%","49.92%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"hcp_type=Other Practice staff<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Other Practice staff","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Other Practice staff","offsetgroup":"Other Practice staff","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["45.32%","45.64%","43.65%","41.88%","42.60%","43.73%","44.94%","44.85%","47.39%","50.00%","46.93%","46.83%","44.47%","44.17%","43.98%","44.54%","44.25%","44.30%","45.00%","45.27%","46.02%","49.31%","47.47%","46.20%","45.66%","46.10%","45.71%","46.91%","46.64%","46.87%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"hcp_type=Unknown<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Unknown","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Unknown","offsetgroup":"Unknown","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00: ...
#
# var gd = document.getElementById('6c883103-f545-40a3-97ac-a61693e44281');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
data = ar.groupby(['hcp_type','appointment_status'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('hcp_type')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='hcp_type', y='Percentage',color='appointment_status',
        title='Appointments per hcp type', template='none', text_auto= True)   
fig.update_layout(barmode='group')
fig.show()
# Out:
# <div>                            <div id="2e06ea2a-f87e-4aed-8ae1-0c6da3802485" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e06ea2a-f87e-4aed-8ae1-0c6da3802485")) {                    Plotly.newPlot(                        "2e06ea2a-f87e-4aed-8ae1-0c6da3802485",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["GP","Other Practice staff","Unknown"],"xaxis":"x","y":["94.26%","88.07%","88.41%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=DNA<br>hcp_type=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"DNA","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"DNA","offsetgroup":"DNA","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["GP","Other Practice staff","Unknown"],"xaxis":"x","y":["2.48%","6.13%","2.78%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Unknown<br>hcp_type=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Unknown","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Unknown","offsetgroup":"Unknown","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["GP","Other Practice staff","Unknown"],"xaxis":"x","y":["3.26%","5.80%","8.81%"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"scatter":[{"type":"scatter"}]}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"hcp_type"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Percentage"}},"legend":{"title":{"text":"appointment_status"},"tracegroupgap":0},"title":{"text":"Appointments per hcp type"},"barmode":"group"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('2e06ea2a-f87e-4aed-8ae1-0c6da3802485');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
data = ar.groupby(['appointment_month','hcp_type'])['count_of_appointments'].agg('sum').reset_index()

fig = px.line(data, x='appointment_month', y='count_of_appointments',
             template='none', color='hcp_type',width=800, height=400)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per month for hcp type', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="7b75cb13-a740-485a-a7c0-10be0d37d783" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b75cb13-a740-485a-a7c0-10be0d37d783")) {                    Plotly.newPlot(                        "7b75cb13-a740-485a-a7c0-10be0d37d783",                        [{"hovertemplate":"hcp_type=GP<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"GP","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"GP","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[14168932,12467976,12839993,8795939,8924583,11054065,11701906,10481447,13187253,13182629,12501963,11759814,11806927,11827794,14391125,12462924,12334764,14050148,13338516,12299022,14487785,14300751,14897749,12654767,13138050,12869711,15127227,11908463,13793934,12893983],"yaxis":"y","type":"scatter"},{"hovertemplate":"hcp_type=Other Practice staff<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Other Practice staff","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other Practice staff","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[12326031,11002550,10498713,6704003,6993557,9047092,10108127,9037362,12660278,14150521,11760406,11021668,10001104,9894163,11973606,10635500,10402894,11866623,11583564,10797821,13126731,14942504,14432800,11614470,11705142,11688107,13528583,11217738,12823200,12105677],"yaxis":"y","type":"scatter"},{"hovertemplate":"hcp_type=Unknown<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Unknown","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Unknown","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis" ...
#
# var gd = document.getElementById('7b75cb13-a740-485a-a7c0-10be0d37d783');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ## Appointment modes

# %%
# 1.3 Total appointments (ar) - mode
# 1.3.1 Pie chart - mode % 
data = ar.groupby(['appointment_month','appointment_mode'])['count_of_appointments'].agg('sum').reset_index()

fig = px.pie(data, values='count_of_appointments', 
             names='appointment_mode', template='none',
             category_orders=
             {'appointment_mode':['Face-to-Face', 'Telephone','Home Visit', 'Video/Online','Unknown']})
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_layout(title = 'Appointments by appointment modes', 
                  xaxis_title = "Month", yaxis_title = "Number of Appointments")
fig.show()
# Out:
# <div>                            <div id="604e06f3-bb22-4f03-9ce1-cedcc668988f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("604e06f3-bb22-4f03-9ce1-cedcc668988f")) {                    Plotly.newPlot(                        "604e06f3-bb22-4f03-9ce1-cedcc668988f",                        [{"direction":"clockwise","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"appointment_mode=%{label}<br>count_of_appointments=%{value}<extra></extra>","labels":["Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Face-to-Face","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Telephone","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Home Visit","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Video/Online","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown","Unknown"],"legendgroup":"","name":"","showlegend":true,"sort":false,"values":[21733394,19230573,15921794,7480941,7729597,9763381,11184673,10388825,15092880,16870816,13886990,13133882,11887083,11850255,14593975,13058306,13032902,15030018,14607857,13717325,17266602,19471561,19031327,15312340,15414102,15531971,18333743,15049567,17630858,16744191,3701775,3322242,6637656,7652390,7813734,9849385,10114285,8742071,10262198,9950370,9954012,9278556,9571141,9546051,11383424,9704359,9436985,10606719,10060423,9149072,10068770,9449544,9993842,8723325,9212553,8820538,10088419,7893805,8792743,8082270,266942,227935,172773,100673,112018,133805,140787,119250,148978,161721,150187,137310,129033,130396,154148,148827,142291,161666,157992,151619,171829,178593,203352,181264,171669,170435,200945,172936,200862,187640,194206,172638,127230,44213,41650,59057,80764,77183,124282,137466,108583,107719,106564,103245,127147,111032,108085,125564,120833,110029,155354,174465,160580,125798,130798,127697,152018,126453,144188,136117,1302979,1151233,1194015,729664,720213,885177,970928,823191,1085917,1181559,961830,878469,798248,769622,966730,857408,788132,860215,792114,724126,859946,1029671,1015969,798049,706352,704619,819913,670299,726857,677860],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"scatter":[{"type":"scatt ...
#
# var gd = document.getElementById('604e06f3-bb22-4f03-9ce1-cedcc668988f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
data = ar.groupby(['appointment_month','appointment_mode'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('appointment_month')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_month', y='Percentage',color='appointment_mode',
        title='Appointments per mode', template='none', text_auto= True,category_orders=
             {'appointment_mode':['Face-to-Face', 'Telephone','Home Visit', 'Video/Online','Unknown']})
#fig.update_layout(barmode="relative")
fig.update_xaxes(dtick="M1", tickangle=45)
fig.show()
# Out:
# <div>                            <div id="c4a14874-9076-4484-b399-f5ef72982312" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4a14874-9076-4484-b399-f5ef72982312")) {                    Plotly.newPlot(                        "c4a14874-9076-4484-b399-f5ef72982312",                        [{"alignmentgroup":"True","hovertemplate":"appointment_mode=Face-to-Face<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Face-to-Face","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Face-to-Face","offsetgroup":"Face-to-Face","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["79.90%","79.78%","66.19%","46.73%","47.08%","47.19%","49.73%","51.56%","56.50%","59.61%","55.41%","55.80%","52.85%","52.90%","53.60%","54.68%","55.44%","56.12%","56.75%","57.51%","60.54%","64.25%","62.59%","60.91%","60.13%","61.26%","61.95%","62.93%","64.12%","64.83%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_mode=Telephone<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Telephone","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Telephone","offsetgroup":"Telephone","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["13.61%","13.78%","27.60%","47.80%","47.59%","47.60%","44.97%","43.38%","38.41%","35.16%","39.72%","39.42%","42.55%","42.62%","41.81%","40.64%","40.14%","39.60%","39.09%","38.36%","35.30%","31.18%","32.87%","34.70%","35.94%","34.79%","34.09%","33.01%","31.98%","31.29%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_mode=Home Visit<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Home Visit","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Home Visit","offsetgroup":"Home Visit","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021 ...
#
# var gd = document.getElementById('c4a14874-9076-4484-b399-f5ef72982312');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container

# %%
data = ar.groupby(['appointment_month','appointment_mode'])['count_of_appointments'].agg('sum').reset_index()

fig = px.line(data, x='appointment_month', y='count_of_appointments',
             template='none', color='appointment_mode',width=800, height=400,
              category_orders=
             {'appointment_mode':['Face-to-Face', 'Telephone','Home Visit', 'Video/Online','Unknown']})
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per month for appointment mode', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="62ab65fc-9097-4d94-8934-ecb7b77038ab" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62ab65fc-9097-4d94-8934-ecb7b77038ab")) {                    Plotly.newPlot(                        "62ab65fc-9097-4d94-8934-ecb7b77038ab",                        [{"hovertemplate":"appointment_mode=Face-to-Face<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Face-to-Face","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Face-to-Face","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[21733394,19230573,15921794,7480941,7729597,9763381,11184673,10388825,15092880,16870816,13886990,13133882,11887083,11850255,14593975,13058306,13032902,15030018,14607857,13717325,17266602,19471561,19031327,15312340,15414102,15531971,18333743,15049567,17630858,16744191],"yaxis":"y","type":"scatter"},{"hovertemplate":"appointment_mode=Telephone<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Telephone","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Telephone","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[3701775,3322242,6637656,7652390,7813734,9849385,10114285,8742071,10262198,9950370,9954012,9278556,9571141,9546051,11383424,9704359,9436985,10606719,10060423,9149072,10068770,9449544,9993842,8723325,9212553,8820538,10088419,7893805,8792743,8082270],"yaxis":"y","type":"scatter"},{"hovertemplate":"appointment_mode=Home Visit<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Home Visit","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Home Visit","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:0 ...
#
# var gd = document.getElementById('62ab65fc-9097-4d94-8934-ecb7b77038ab');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}

# %% [markdown]
# ## Waiting time between booking and appointment

# %%
data = ar.groupby(['appointment_month','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()

fig = px.pie(data, values='count_of_appointments', 
             names='time_between_book_and_appointment', 
             category_orders={'time_between_book_and_appointment': 
                              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
                               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality']},
             template='none')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_layout(title = 'Number of appointments per waiting time', 
                  xaxis_title = "Month", yaxis_title = "Number of Appointments")
fig.show()
# Out:
# <div>                            <div id="bd521b3f-648c-4a35-9eb5-551e461e340c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd521b3f-648c-4a35-9eb5-551e461e340c")) {                    Plotly.newPlot(                        "bd521b3f-648c-4a35-9eb5-551e461e340c",                        [{"direction":"clockwise","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"time_between_book_and_appointment=%{label}<br>count_of_appointments=%{value}<extra></extra>","labels":["Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","Same Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","1 Day","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","2 to 7 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","8  to 14 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","15  to 21 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","22  to 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","More than 28 Days","Unknown / Data Quality","Unknown / Data Quality","Unknown / Data Quality","Unknown / Data Quality","Unknown / Data Quality","Unknown / Data Quality","Unknown / Data Quality","Unknown / Data Qual ...
#
# var gd = document.getElementById('bd521b3f-648c-4a35-9eb5-551e461e340c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
data = ar.groupby(['appointment_month','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('appointment_month')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_month', y='Percentage',color='time_between_book_and_appointment',
        title='Appointments per waiting time', template='none', text_auto= True,                           
             category_orders={'time_between_book_and_appointment': 
                              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
                               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality']})
fig.update_xaxes(dtick="M1", tickangle=45)
fig.show()
# Out:
# <div>                            <div id="84e6255d-4976-4b3f-acef-66650657ac00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84e6255d-4976-4b3f-acef-66650657ac00")) {                    Plotly.newPlot(                        "84e6255d-4976-4b3f-acef-66650657ac00",                        [{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=Same Day<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Same Day","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Same Day","offsetgroup":"Same Day","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["42.43%","41.73%","45.51%","63.34%","62.59%","57.36%","52.21%","50.46%","44.85%","40.99%","45.25%","45.57%","48.34%","47.70%","46.12%","45.41%","44.82%","45.60%","45.36%","46.33%","43.22%","40.25%","42.25%","45.82%","46.66%","45.01%","44.58%","45.16%","44.40%","44.38%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=1 Day<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"1 Day","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"1 Day","offsetgroup":"1 Day","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["7.15%","6.91%","7.58%","9.51%","11.10%","10.97%","10.86%","9.95%","9.22%","9.06%","9.12%","9.84%","10.83%","10.54%","9.90%","9.64%","9.31%","8.92%","9.11%","8.46%","9.35%","8.57%","8.24%","8.83%","9.11%","8.96%","9.15%","8.74%","8.26%","8.47%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=2 to 7 Days<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"2 to 7 Days","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"2 to 7 Days","offsetgroup":"2 to 7 Days","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-1 ...

# %%
data = ar.groupby(['appointment_month','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()

fig = px.line(data, x='appointment_month', y='count_of_appointments',
             template='none', color='time_between_book_and_appointment',width=1000, height=400,
                           category_orders={'time_between_book_and_appointment': 
                              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
                               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality']})
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per month for waiting time', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="6e9c9321-cae7-4d30-a72e-297fde1c838e" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e9c9321-cae7-4d30-a72e-297fde1c838e")) {                    Plotly.newPlot(                        "6e9c9321-cae7-4d30-a72e-297fde1c838e",                        [{"hovertemplate":"time_between_book_and_appointment=Same Day<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Same Day","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Same Day","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[11541694,10058743,10947395,10139567,10274928,11867769,11742601,10167085,11980849,11600881,11339810,10724259,10872970,10684618,12556265,10843427,10537600,12214163,11675905,11051004,12326333,12197576,12847122,11519536,11961272,11412540,13192245,10799188,12207903,11461923],"yaxis":"y","type":"scatter"},{"hovertemplate":"time_between_book_and_appointment=1 Day<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"1 Day","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1 Day","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[1945711,1666076,1822926,1523077,1821810,2268962,2443479,2005241,2464063,2564396,2285210,2315757,2435465,2361443,2695469,2301670,2188719,2389097,2344552,2018319,2666072,2598516,2506532,2219212,2334274,2272923,2709362,2088881,2270686,2188197],"yaxis":"y","type":"scatter"},{"hovertemplate":"time_between_book_and_appointment=2 to 7 Days<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"2 to 7 Days","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2 to 7 Days","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00 ...

# %% [markdown]
# ## Appointment Status

# %%
data = ar.groupby(['appointment_month','appointment_status'])['count_of_appointments'].agg('sum').reset_index()

fig = px.line(data, x='appointment_month', y='count_of_appointments',
             template='none', color='appointment_status',width=1000, height=400)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per appointment status', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="3d12dc53-e71e-464e-9659-e275e49ba323" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d12dc53-e71e-464e-9659-e275e49ba323")) {                    Plotly.newPlot(                        "3d12dc53-e71e-464e-9659-e275e49ba323",                        [{"hovertemplate":"appointment_status=Attended<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Attended","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Attended","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[24538291,21640067,20718865,13982824,14962850,18943022,20606888,18438932,23988492,25529275,23072059,21592221,20645718,20736205,25289991,22056413,21779605,24815463,23761001,22081765,25757066,27170506,27667665,22853483,23597196,23351939,27170002,21948814,25343941,23715317],"yaxis":"y","type":"scatter"},{"hovertemplate":"appointment_status=DNA<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"DNA","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"DNA","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[1298269,1215154,1166314,478766,449057,594382,698327,669462,1145971,1358138,1021408,996416,899833,804659,964719,893723,878219,1030367,1029665,949137,1321348,1565624,1428087,1198866,1076013,1076658,1289888,1045455,1199518,1167790],"yaxis":"y","type":"scatter"},{"hovertemplate":"appointment_status=Unknown<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Unknown","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Unknown","orientation":"v","showlegend":true,"x":["2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":[1362736,1249400,2168289,154 ...
#
# var gd = document.getElementById('3d12dc53-e71e-464e-9659-e275e49ba323');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
data = ar.groupby(['appointment_month','appointment_status','season'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('appointment_month')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_month', y='Percentage', color='season',
             category_orders={'season': ['Spring', 'Summer', 'Autumn', 'Winter']},
             facet_row='appointment_status',
            title='Total appointments per status', template='none', text_auto= True)   

fig.update_xaxes(dtick="M1", tickangle=45)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.show()
# Out:
# <div>                            <div id="3d6e1142-7dec-4e22-8324-90b1562df966" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d6e1142-7dec-4e22-8324-90b1562df966")) {                    Plotly.newPlot(                        "3d6e1142-7dec-4e22-8324-90b1562df966",                        [{"alignmentgroup":"True","hovertemplate":"season=Spring<br>appointment_status=Attended<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Spring","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Spring","offsetgroup":"Spring","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x3","y":["87.35%","91.14%","91.55%","92.36%","92.65%","92.65%","91.79%","92.17%","91.82%"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"season=Spring<br>appointment_status=DNA<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Spring","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Spring","offsetgroup":"Spring","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x2","y":["2.99%","2.74%","2.87%","3.74%","3.74%","3.85%","4.37%","4.36%","4.52%"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"season=Spring<br>appointment_status=Unknown<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Spring","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Spring","offsetgroup":"Spring","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00"],"xaxis":"x","y":["9.66%","6.12%","5.57%","3.89%","3.62%","3.50%","3.84%","3.46%","3.66%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"season=Summer<br>appointment_status=Attended<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Summer","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00"],"xaxis":"x3","y":["91.62%","91.51%","89.80%","92.31%","92.58%","90.30%"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"season=Summer<br>appointment_status=DNA<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Summer","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00"],"xaxis":"x2","y":["3.10%","3.32%","4.29%","4.00%","3.98%","4.63%"],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"season=Summer<br>appointment_status=Unknown<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Summer","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":false,"textposition":"auto","tex ...

# %% [markdown]
# # Patient pathway

# %%
data = ar.groupby(['month_year','hcp_type','appointment_mode','appointment_status'])['count_of_appointments'].agg('sum').reset_index()

px.bar(data, x='appointment_mode', y='count_of_appointments',color='appointment_status',
       facet_col ='hcp_type',
       title="Number of appointment per hcp types and appointment mode", template='none', height=400)
# Out:
# <div>                            <div id="ba4342a4-b7a7-4dfb-998d-5ab934a8eed6" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba4342a4-b7a7-4dfb-998d-5ab934a8eed6")) {                    Plotly.newPlot(                        "ba4342a4-b7a7-4dfb-998d-5ab934a8eed6",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x","y":[2783535,24067,5052041,218747,17644,4914660,42630,6668804,162744,55108,5875208,57926,5177900,97486,56671,3771652,32259,5865669,192139,39507,5250929,50432,6228512,129649,52626,4494497,39423,6420174,162045,48624,5823991,57747,5904764,120249,57173,8758600,65931,2203204,331118,110006,4419078,37542,6601588,155782,53071,6078994,57283,5892904,118153,59362,10039619,78245,2467056,380120,127145,4305117,36629,6638823,155864,53617,6019015,57118,6225434,119626,60448,4071203,36761,6682219,249172,39990,5581837,52340,6858986,128834,57431,3654242,32174,6501055,246282,26464,5828660,51718,7297923,138969,61434,6676370,64424,5283548,95428,62522,6552259,47493,4494277,328690,72162,5537137,45217,7878942,197247,65181,7303051,68426,6745213,128511,69857,3021757,25873,5152591,212822,17695,5011871,44101,6512193,126080,53750,7035107,67730,5785702,105193,66023,4754018,39776,6889822,177010,51847,7001902,63661,6776847,146523,71645,5187881,40743,6926716,200495,53719,6629765,55171,6447566,146070,66127,4983400,39282,7019146,220195,54115,6436078,55186,6897524,145532,63382],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=Ot ...

# %%
data = ar.groupby(['hcp_type','appointment_mode','appointment_status','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby(['hcp_type','appointment_mode','time_between_book_and_appointment'])['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_mode', y='Percentage',color='appointment_status',
             facet_row='time_between_book_and_appointment', animation_frame = 'hcp_type',
             category_orders=
             {'time_between_book_and_appointment': 
              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality'],
              'appointment_mode':['Face-to-Face', 'Telephone','Home Visit', 'Video/Online','Unknown']},
             title='Appointment attendance % per hcp, mode, waiting time', template='none', text_auto= True,
             width=800, height=1500)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.update_xaxes(dtick="M1", tickangle=45)

fig.show()
# Out:
# <div>                            <div id="7fbc7ab0-a2a6-4372-a566-778ad4304bb9" class="plotly-graph-div" style="height:1500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fbc7ab0-a2a6-4372-a566-778ad4304bb9")) {                    Plotly.newPlot(                        "7fbc7ab0-a2a6-4372-a566-778ad4304bb9",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=Same Day<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x8","y":["96.33%","77.75%","97.25%","94.72%","95.51%"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=1 Day<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x7","y":["93.37%","75.71%","95.31%","91.25%","95.45%"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=2 to 7 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x6","y":["90.79%","73.08%","94.84%","88.63%","93.28%"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=8  to 14 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x5","y":["87.05%","65.19%","93.21%","83.20%","90.40%"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=15  to 21 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x4","y":["84.07%","62.35%","91.69%","77.41%","86.78%"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=22  to 28 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x3","y":["81.13%","60.41%","89.77%","72.21%","86.37%"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=More  ...

# %%
data = ar.groupby(['hcp_type','appointment_mode','appointment_status','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby(['hcp_type','appointment_mode','time_between_book_and_appointment'])['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_mode', y='Percentage',color='appointment_status',
             facet_row='time_between_book_and_appointment', animation_frame = 'hcp_type',
             category_orders=
             {'time_between_book_and_appointment': 
              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality'],
              'appointment_mode':['Face-to-Face', 'Telephone','Home Visit', 'Video/Online','Unknown']},
             title='Appointment attendance % per hcp, mode, waiting time', template='none', text_auto= True,
             width=800, height=1500)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.update_xaxes(dtick="M1", tickangle=45)

fig.show()
# Out:
# <div>                            <div id="1b0639e4-81a9-4d0d-a710-de9f5834a1eb" class="plotly-graph-div" style="height:1500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b0639e4-81a9-4d0d-a710-de9f5834a1eb")) {                    Plotly.newPlot(                        "1b0639e4-81a9-4d0d-a710-de9f5834a1eb",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=Same Day<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x8","y":["96.33%","77.75%","97.25%","94.72%","95.51%"],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=1 Day<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x7","y":["93.37%","75.71%","95.31%","91.25%","95.45%"],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=2 to 7 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x6","y":["90.79%","73.08%","94.84%","88.63%","93.28%"],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=8  to 14 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x5","y":["87.05%","65.19%","93.21%","83.20%","90.40%"],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=15  to 21 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x4","y":["84.07%","62.35%","91.69%","77.41%","86.78%"],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=22  to 28 Days<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x3","y":["81.13%","60.41%","89.77%","72.21%","86.37%"],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=More  ...

# %%
data = ar.groupby(['region','hcp_type','appointment_mode','appointment_status','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby(['region','hcp_type','appointment_mode','time_between_book_and_appointment'])['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_mode', y='Percentage',color='appointment_status',
             facet_col='hcp_type',
             facet_row='time_between_book_and_appointment', animation_frame = 'region',
             category_orders=
             {'time_between_book_and_appointment': 
              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality'],
              'appointment_mode':['Face-to-Face', 'Telephone','Home Visit', 'Video/Online','Unknown']},
             title='Appointment attendance % per region', template='none', text_auto= True,
             width=1500, height=1500)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.update_xaxes(dtick="M1", tickangle=45)

fig.show()
# Out:
# <div>                            <div id="ad8d9b06-569b-4686-b979-1979c3573281" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad8d9b06-569b-4686-b979-1979c3573281")) {                    Plotly.newPlot(                        "ad8d9b06-569b-4686-b979-1979c3573281",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=East of England<br>time_between_book_and_appointment=Same Day<br>hcp_type=GP<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x22","y":["97.62%","83.35%","98.40%","98.27%","98.02%"],"yaxis":"y22","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=East of England<br>time_between_book_and_appointment=Same Day<br>hcp_type=Other Practice staff<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x23","y":["94.76%","89.58%","97.24%","93.80%","95.19%"],"yaxis":"y23","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=East of England<br>time_between_book_and_appointment=Same Day<br>hcp_type=Unknown<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x24","y":["82.90%","80.04%","95.00%","98.18%","71.88%"],"yaxis":"y24","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=East of England<br>time_between_book_and_appointment=1 Day<br>hcp_type=GP<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x19","y":["94.60%","82.62%","96.47%","96.26%","96.37%"],"yaxis":"y19","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=East of England<br>time_between_book_and_appointment=1 Day<br>hcp_type=Other Practice staff<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x20","y":["90.39%","86.25%","94.37%","85.21%","92.49%"],"yaxis":"y20","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>region=East of England<br>time_between_book_and_appointment=1 Day<br>hcp_type=Unknown<br>appointment_mode=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Face-to-Face","Home Visit","Telephone","Unknown"],"xaxis":"x21","y":["58.00%","75.71%","92.12%", ...

# %%
data = ar.groupby(['month_year','hcp_type','appointment_mode','time_between_book_and_appointment','appointment_status'])['count_of_appointments'].agg('sum').reset_index()

fig = px.bar(data, x='appointment_mode', y='count_of_appointments',color='appointment_status',
       facet_row ='time_between_book_and_appointment', animation_frame='hcp_type',
       category_orders={'time_between_book_and_appointment': 
                        ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
                         '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality']},
                        title="Number of Appointments", template='none', height=1900)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
# Out:
# <div>                            <div id="6bf8f591-4b0d-4615-be1d-90560892a658" class="plotly-graph-div" style="height:1900px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bf8f591-4b0d-4615-be1d-90560892a658")) {                    Plotly.newPlot(                        "6bf8f591-4b0d-4615-be1d-90560892a658",                        [{"alignmentgroup":"True","hovertemplate":"appointment_status=Attended<br>hcp_type=GP<br>time_between_book_and_appointment=Same Day<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Attended","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Attended","offsetgroup":"Attended","orientation":"v","showlegend":true,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online","Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x8","y":[2139356,18636,3991732,171722,11195,2724647,28399,4054219,97076,24445,3293003,39401,3204316,58875,25159,2336623,22377,3890979,124770,22041,3018853,34540,3875164,81161,23662,2600282,27509,4136042,99431,24881,3368500,40001,3771471,74751,27184,4478195,48682,1435129,184703,22511,2564882,25284,4159302,95946,25340,3364146,37907,3588461,70326,27560,5170695,58917,1621977,214199,25471,2562607,25154,4281530,97318,26342,3434364,38567,3900091,74449,29867,2571882,25294,4490690,163964,22936,3117232,35402,4144796,77470,25451,2496945,22611,4662319,171817,15884,3250803,35311,4413108,84188,26552,3697275,42491,3253448,58415,24794,3519700,35150,2936583,198939,16005,3093059,29966,4796936,118499,29114,3987928,45341,4067970,76652,31613,2237340,19137,3933486,160504,10610,2742102,29888,3878479,74876,22994,3857963,45091,3525672,62572,26603,2747101,27028,4339811,106823,27355,3796477,42560,4093477,87739,31813,2797641,27247,4395346,117978,26851,3504591,37826,3931166,87685,25357,2825611,27010,4531182,133365,27384,3443198,37034,4157782,86758,26057],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"appointment_ ...

# %% [markdown]
# # Actual Duration

# %%
data = ad.groupby(['actual_duration','month_year'])['count_of_appointments'].agg('sum').reset_index()

fig = px.bar(data, x='month_year', y='count_of_appointments',
              category_orders={'month_year': 
                        ['Dec-2021', 'Jan-2022', 'Feb-2022', 'Mar-2022', 'Apr-2022',
                         'May-2022', 'Jun-2022'],
                               'actual_duration':['1-5 Minutes','6-10 Minutes','11-15 Minutes',
                                                  '16-20 Minutes','21-30 Minutes','31-60 Minutes'
                                                  'Unknown / Data Quality']},
             template='none', color='actual_duration',width=1000, height=400)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per actual duration', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="e3c64ee2-9452-4e9b-9312-d7415a3f0912" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3c64ee2-9452-4e9b-9312-d7415a3f0912")) {                    Plotly.newPlot(                        "e3c64ee2-9452-4e9b-9312-d7415a3f0912",                        [{"alignmentgroup":"True","hovertemplate":"actual_duration=1-5 Minutes<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"1-5 Minutes","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"1-5 Minutes","offsetgroup":"1-5 Minutes","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-2022","Jan-2022","Jun-2022","Mar-2022","May-2022"],"xaxis":"x","y":[3714437,4266686,3908364,3975252,3962534,4570114,4203478],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"actual_duration=6-10 Minutes<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"6-10 Minutes","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"6-10 Minutes","offsetgroup":"6-10 Minutes","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-2022","Jan-2022","Jun-2022","Mar-2022","May-2022"],"xaxis":"x","y":[4422913,4654000,4695914,4778719,4726440,5489184,5033645],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"actual_duration=11-15 Minutes<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"11-15 Minutes","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"11-15 Minutes","offsetgroup":"11-15 Minutes","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-2022","Jan-2022","Jun-2022","Mar-2022","May-2022"],"xaxis":"x","y":[3297961,3280132,3508227,3537308,3596802,4095290,3845162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"actual_duration=16-20 Minutes<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"16-20 Minutes","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"16-20 Minutes","offsetgroup":"16-20 Minutes","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-2022","Jan-2022","Jun-2022","Mar-2022","May-2022"],"xaxis":"x","y":[2095851,2023774,2238822,2242739,2313930,2607518,2481613],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"actual_duration=21-30 Minutes<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"21-30 Minutes","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"21-30 Minutes","offsetgroup":"21-30 Minutes","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-2022","Jan-2022","Jun-2022","Mar-2022","May-2022"],"xaxis":"x","y":[1958618,1885864,2116476,2125583,2159206,2450292,2330326],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"actual_duration=31-60 Minutes<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"31-60 Minutes","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"31-60 Minutes","offsetgroup":"31-60 Minutes","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-2022","Jan-2022","Jun-2022","Mar-2022","May-2022"],"xaxis":"x","y":[1177878,1163515,1295696,1310454,1280180,1485532,1390177],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"actual_duration=Unknown / Data Quality<br>month_year=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Unknown / Data Quality","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"Unknown / Data Quality","offsetgroup":"Unknown / Data Quality","orientation":"v","showlegend":true,"textposition":"auto","x":["Apr-2022","Dec-2021","Feb-202 ...
#
# var gd = document.getElementById('e3c64ee2-9452-4e9b-9312-d7415a3f0912');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Appointment Distribution [HCP type, Appointment mode, Waiting time, Final Status]

data = ad.groupby(['actual_duration','region'])['count_of_appointments'].sum().reset_index()

fig =px.sunburst(data, 
                 path=['actual_duration','region'],
                 values='count_of_appointments',
                       title="Appointment duartion per region",
                  width=750, height=750, template = 'none')
fig.update_traces(textinfo="label+percent parent")
fig.show()
# Out:
# <div>                            <div id="8b1f5972-46d7-475d-8736-1fca2de6fed1" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b1f5972-46d7-475d-8736-1fca2de6fed1")) {                    Plotly.newPlot(                        "8b1f5972-46d7-475d-8736-1fca2de6fed1",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_of_appointments=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["1-5 Minutes/East of England","11-15 Minutes/East of England","16-20 Minutes/East of England","21-30 Minutes/East of England","31-60 Minutes/East of England","6-10 Minutes/East of England","Unknown / Data Quality/East of England","1-5 Minutes/London","11-15 Minutes/London","16-20 Minutes/London","21-30 Minutes/London","31-60 Minutes/London","6-10 Minutes/London","Unknown / Data Quality/London","1-5 Minutes/Midlands","11-15 Minutes/Midlands","16-20 Minutes/Midlands","21-30 Minutes/Midlands","31-60 Minutes/Midlands","6-10 Minutes/Midlands","Unknown / Data Quality/Midlands","1-5 Minutes/North East and Yorkshire","11-15 Minutes/North East and Yorkshire","16-20 Minutes/North East and Yorkshire","21-30 Minutes/North East and Yorkshire","31-60 Minutes/North East and Yorkshire","6-10 Minutes/North East and Yorkshire","Unknown / Data Quality/North East and Yorkshire","1-5 Minutes/North West","11-15 Minutes/North West","16-20 Minutes/North West","21-30 Minutes/North West","31-60 Minutes/North West","6-10 Minutes/North West","Unknown / Data Quality/North West","1-5 Minutes/South East","11-15 Minutes/South East","16-20 Minutes/South East","21-30 Minutes/South East","31-60 Minutes/South East","6-10 Minutes/South East","Unknown / Data Quality/South East","1-5 Minutes/South West","11-15 Minutes/South West","16-20 Minutes/South West","21-30 Minutes/South West","31-60 Minutes/South West","6-10 Minutes/South West","Unknown / Data Quality/South West","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality"],"labels":["East of England","East of England","East of England","East of England","East of England","East of England","East of England","London","London","London","London","London","London","London","Midlands","Midlands","Midlands","Midlands","Midlands","Midlands","Midlands","North East and Yorkshire","North East and Yorkshire","North East and Yorkshire","North East and Yorkshire","North East and Yorkshire","North East and Yorkshire","North East and Yorkshire","North West","North West","North West","North West","North West","North West","North West","South East","South East","South East","South East","South East","South East","South East","South West","South West","South West","South West","South West","South West","South West","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality"],"name":"","parents":["1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality","1-5 Minutes","11-15 Minutes","16-20 Minutes","21-30 Minutes","31-60 Minutes","6-10 Minutes","Unknown / Data Quality",""," ...
#
# var gd = document.getElementById('8b1f5972-46d7-475d-8736-1fca2de6fed1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %% [markdown]
# ## National Category

# %%
data = nc.groupby(['national_category','appointment_month'])['count_of_appointments'].agg('sum').reset_index()
data['Percentage'] = 100 * data['count_of_appointments'] / data.groupby('appointment_month')['count_of_appointments'].transform('sum')
data['Percentage'] = data['Percentage'].apply(lambda x: '{0:.2f}%'.format(x))

fig = px.bar(data, x='appointment_month', y='Percentage',color='national_category',
        title='Appointment per national category', template='none', text_auto= True)                           
fig.update_xaxes(dtick="M1", tickangle=45)
fig.show()
# Out:
# <div>                            <div id="0305e859-b71b-4c00-b9fc-1251d62e9ef0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0305e859-b71b-4c00-b9fc-1251d62e9ef0")) {                    Plotly.newPlot(                        "0305e859-b71b-4c00-b9fc-1251d62e9ef0",                        [{"alignmentgroup":"True","hovertemplate":"national_category=Care Home Needs Assessment & Personalised Care and Support Planning<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Care Home Needs Assessment & Personalised Care and Support Planning","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Care Home Needs Assessment & Personalised Care and Support Planning","offsetgroup":"Care Home Needs Assessment & Personalised Care and Support Planning","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":["0.12%","0.12%","0.11%","0.13%","0.14%","0.15%","0.15%","0.15%","0.15%","0.16%","0.16%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"national_category=Care Home Visit<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Care Home Visit","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Care Home Visit","offsetgroup":"Care Home Visit","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":["0.20%","0.19%","0.18%","0.20%","0.22%","0.22%","0.22%","0.22%","0.22%","0.24%","0.24%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"national_category=Clinical Triage<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"Clinical Triage","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Clinical Triage","offsetgroup":"Clinical Triage","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":["15.53%","14.44%","13.09%","13.78%","14.40%","14.74%","14.38%","14.04%","13.81%","13.36%","13.13%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"national_category=General Consultation Acute<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"General Consultation Acute","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"General Consultation Acute","offsetgroup":"General Consultation Acute","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":["17.95%","16.95%","15.98%","17.32%","18.65%","18.68%","18.80%","18.86%","19.02%","18.94%","18.90%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"national_category=General Consultation Routine<br>appointment_month=%{x}<br>Percentage=%{y}<extra></extra>","legendgroup":"General Consultation Routine","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"General Consultation Routine","offsetgroup":"General Consultation Routine","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":["32.52%","31.77%","30.55%","32.16%","32.31%","33.72%","33.78%","34.04%","33.45%","33.90%","33.65%"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"national_category=Group Consultation and Group Education<br> ...

# %%
data = nc.groupby(['national_category','appointment_month'])['count_of_appointments'].agg('sum').reset_index()

fig = px.line(data, x='appointment_month', y='count_of_appointments',
             template='none', color='national_category',width=1000, height=400)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_yaxes(rangemode="tozero")
fig.update_layout(title = 'Number of appointments per national category', 
                  xaxis_title = "Month", yaxis_title = "Numbers of appointments")
fig.show()
# Out:
# <div>                            <div id="ab3cef0c-4a88-4457-983b-30b80eb0437c" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab3cef0c-4a88-4457-983b-30b80eb0437c")) {                    Plotly.newPlot(                        "ab3cef0c-4a88-4457-983b-30b80eb0437c",                        [{"hovertemplate":"national_category=Care Home Needs Assessment & Personalised Care and Support Planning<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Care Home Needs Assessment & Personalised Care and Support Planning","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Care Home Needs Assessment & Personalised Care and Support Planning","orientation":"v","showlegend":true,"x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":[29676,33503,32441,38827,34653,37988,37219,43189,35282,42904,40222],"yaxis":"y","type":"scatter"},{"hovertemplate":"national_category=Care Home Visit<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Care Home Visit","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Care Home Visit","orientation":"v","showlegend":true,"x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":[47583,53519,53713,61816,55230,55860,55078,65413,53715,64806,61546],"yaxis":"y","type":"scatter"},{"hovertemplate":"national_category=Clinical Triage<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Clinical Triage","line":{"color":"#2CA02C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Clinical Triage","orientation":"v","showlegend":true,"x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":[3704207,4118862,3966561,4189237,3621415,3777487,3646672,4155846,3301285,3674229,3391163],"yaxis":"y","type":"scatter"},{"hovertemplate":"national_category=General Consultation Acute<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"General Consultation Acute","line":{"color":"#D62728","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"General Consultation Acute","orientation":"v","showlegend":true,"x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":[4280920,4834413,4843309,5265514,4689373,4787643,4767965,5581504,4548963,5208791,4882755],"yaxis":"y","type":"scatter"},{"hovertemplate":"national_category=General Consultation Routine<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"General Consultation Routine","line":{"color":"#9467BD","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"General Consultation Routine","orientation":"v","showlegend":true,"x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":[7756045,9060243,9256788,9778682,8123938,8645563,8565715,10074249,7998377,9320538,8691384],"yaxis":"y","type":"scatter"},{"hovertemplate":"national_category=Group Consultation and Group Education<br>appointment_month=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Group Consultation and Group Education","line":{"color":"#8C564B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Group Consultation and Group Education","orientation":"v","showlegend":true,"x":["2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06"],"xaxis":"x","y":[51 ...

# %%
# Appointment per national category

data = nc.groupby(['service_setting','national_category'])['count_of_appointments'].agg('sum').reset_index()
new_data = data.sort_values('count_of_appointments',ascending = False)

fig = px.bar(new_data, x='national_category', y='count_of_appointments', 
             color='service_setting',
             text='count_of_appointments', template='none')
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_traces(opacity=0.85)
fig.update_xaxes(dtick="M1", tickangle=45)
fig.update_layout(title = 'Appointment per national category', 
                  xaxis_title = 'National Category', yaxis_title = "Number of Appointments")
fig.show()
# Out:
# <div>                            <div id="5f6c3784-a935-42e6-90b2-855eeaf4a9fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f6c3784-a935-42e6-90b2-855eeaf4a9fe")) {                    Plotly.newPlot(                        "5f6c3784-a935-42e6-90b2-855eeaf4a9fe",                        [{"alignmentgroup":"True","hovertemplate":"service_setting=General Practice<br>national_category=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"General Practice","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"General Practice","offsetgroup":"General Practice","orientation":"v","showlegend":true,"text":[93358462.0,52059940.0,40246576.0,26376358.0,24997475.0,24986338.0,2872873.0,2040497.0,1312506.0,536382.0,517649.0,469974.0,363566.0,316586.0,181371.0,116053.0,59085.0],"textposition":"outside","x":["General Consultation Routine","General Consultation Acute","Clinical Triage","Planned Clinics","Inconsistent Mapping","Planned Clinical Procedure","Unplanned Clinical Activity","Home Visit","Structured Medication Review","Care Home Visit","Patient contact during Care Home Round","Service provided by organisation external to the practice","Walk-in","Care Home Needs Assessment & Personalised Care and Support Planning","Social Prescribing Service","Non-contractual chargeable work","Group Consultation and Group Education"],"xaxis":"x","y":[93358462,52059940,40246576,26376358,24997475,24986338,2872873,2040497,1312506,536382,517649,469974,363566,316586,181371,116053,59085],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}","opacity":0.85},{"alignmentgroup":"True","hovertemplate":"service_setting=Unmapped<br>national_category=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Unmapped","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"Unmapped","offsetgroup":"Unmapped","orientation":"v","showlegend":true,"text":[11080810.0],"textposition":"outside","x":["Unmapped"],"xaxis":"x","y":[11080810],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}","opacity":0.85},{"alignmentgroup":"True","hovertemplate":"service_setting=Primary Care Network<br>national_category=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Primary Care Network","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"Primary Care Network","offsetgroup":"Primary Care Network","orientation":"v","showlegend":true,"text":[2136309.0,866492.0,812440.0,612029.0,507640.0,342429.0,279704.0,270891.0,240807.0,174437.0,94263.0,77747.0,68052.0,63805.0,5848.0,3832.0,661.0],"textposition":"outside","x":["General Consultation Routine","Planned Clinics","Inconsistent Mapping","General Consultation Acute","Structured Medication Review","Clinical Triage","Social Prescribing Service","Patient contact during Care Home Round","Planned Clinical Procedure","Service provided by organisation external to the practice","Unplanned Clinical Activity","Care Home Needs Assessment & Personalised Care and Support Planning","Home Visit","Care Home Visit","Walk-in","Non-contractual chargeable work","Group Consultation and Group Education"],"xaxis":"x","y":[2136309,866492,812440,612029,507640,342429,279704,270891,240807,174437,94263,77747,68052,63805,5848,3832,661],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}","opacity":0.85},{"alignmentgroup":"True","hovertemplate":"service_setting=Other<br>national_category=%{x}<br>count_of_appointments=%{text}<extra></extra>","legendgroup":"Other","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"text":[1642532.0,1377569.0,606115.0,575083.0,515480.0,302533.0,178579.0,51300.0,34583.0,32417.0,30832.0,19764.0,18581.0,17196.0,8773.0,8501.0,238.0],"textposition":"outside","x":["Inconsisten ...
#
# var gd = document.getElementById('5f6c3784-a935-42e6-90b2-855eeaf4a9fe');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Appointment Distribution per region,service_setting,national_category

data = nc.groupby(['service_setting','national_category'])['count_of_appointments'].sum().reset_index()

fig =px.sunburst(data, 
                 path=['service_setting','national_category'],
                 values='count_of_appointments',
                       title="Total Appointment Distribution [region,service_setting,national_category]",
                  width=750, height=750,template = 'none')
fig.update_traces(textinfo="label+percent parent")
fig.show()
# Out:
# <div>                            <div id="e2a041c1-3e8b-4b63-b252-9d7394e4cc58" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2a041c1-3e8b-4b63-b252-9d7394e4cc58")) {                    Plotly.newPlot(                        "e2a041c1-3e8b-4b63-b252-9d7394e4cc58",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_of_appointments=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Extended Access Provision/Care Home Needs Assessment & Personalised Care and Support Planning","General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","Other/Care Home Needs Assessment & Personalised Care and Support Planning","Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","Extended Access Provision/Care Home Visit","General Practice/Care Home Visit","Other/Care Home Visit","Primary Care Network/Care Home Visit","Extended Access Provision/Clinical Triage","General Practice/Clinical Triage","Other/Clinical Triage","Primary Care Network/Clinical Triage","Extended Access Provision/General Consultation Acute","General Practice/General Consultation Acute","Other/General Consultation Acute","Primary Care Network/General Consultation Acute","Extended Access Provision/General Consultation Routine","General Practice/General Consultation Routine","Other/General Consultation Routine","Primary Care Network/General Consultation Routine","Extended Access Provision/Group Consultation and Group Education","General Practice/Group Consultation and Group Education","Other/Group Consultation and Group Education","Primary Care Network/Group Consultation and Group Education","Extended Access Provision/Home Visit","General Practice/Home Visit","Other/Home Visit","Primary Care Network/Home Visit","Extended Access Provision/Inconsistent Mapping","General Practice/Inconsistent Mapping","Other/Inconsistent Mapping","Primary Care Network/Inconsistent Mapping","Extended Access Provision/Non-contractual chargeable work","General Practice/Non-contractual chargeable work","Other/Non-contractual chargeable work","Primary Care Network/Non-contractual chargeable work","Extended Access Provision/Patient contact during Care Home Round","General Practice/Patient contact during Care Home Round","Other/Patient contact during Care Home Round","Primary Care Network/Patient contact during Care Home Round","Extended Access Provision/Planned Clinical Procedure","General Practice/Planned Clinical Procedure","Other/Planned Clinical Procedure","Primary Care Network/Planned Clinical Procedure","Extended Access Provision/Planned Clinics","General Practice/Planned Clinics","Other/Planned Clinics","Primary Care Network/Planned Clinics","Extended Access Provision/Service provided by organisation external to the practice","General Practice/Service provided by organisation external to the practice","Other/Service provided by organisation external to the practice","Primary Care Network/Service provided by organisation external to the practice","Extended Access Provision/Social Prescribing Service","General Practice/Social Prescribing Service","Other/Social Prescribing Service","Primary Care Network/Social Prescribing Service","Extended Access Provision/Structured Medication Review","General Practice/Structured Medication Review","Other/Structured Medication Review","Primary Care Network/Structured Medication Review","Unmapped/Unmapped","Extended Access Provision/Unplanned Clinical Activity","General Practice/Unplanned Clinical Activity","Other/Unplanned Clinical Activity","Primary Care Network/Unplanned Clinical Activity","Extended Access Provision/Walk-in","General Practice/Walk-in","Other/Walk-in","Pri ...

# %%
# Appointment Distribution [region,service_setting,national_category]

data = nc.groupby(['region','service_setting','national_category'])['count_of_appointments'].sum().reset_index()

fig =px.sunburst(data, 
                 path=['region','service_setting','national_category'],
                 values='count_of_appointments',
                       title="Total Appointment Distribution [region,service_setting,national_category]",
                  width=750, height=750,template = 'none')
fig.update_traces(textinfo="label+percent parent")
fig.show()
# Out:
# <div>                            <div id="541b758c-e8b7-4621-bbbf-a7b989199e4c" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("541b758c-e8b7-4621-bbbf-a7b989199e4c")) {                    Plotly.newPlot(                        "541b758c-e8b7-4621-bbbf-a7b989199e4c",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_of_appointments=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["East of England/Extended Access Provision/Care Home Needs Assessment & Personalised Care and Support Planning","London/Extended Access Provision/Care Home Needs Assessment & Personalised Care and Support Planning","Midlands/Extended Access Provision/Care Home Needs Assessment & Personalised Care and Support Planning","South East/Extended Access Provision/Care Home Needs Assessment & Personalised Care and Support Planning","South West/Extended Access Provision/Care Home Needs Assessment & Personalised Care and Support Planning","East of England/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","London/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","Midlands/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","North East and Yorkshire/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","North West/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","South East/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","South West/General Practice/Care Home Needs Assessment & Personalised Care and Support Planning","East of England/Other/Care Home Needs Assessment & Personalised Care and Support Planning","London/Other/Care Home Needs Assessment & Personalised Care and Support Planning","Midlands/Other/Care Home Needs Assessment & Personalised Care and Support Planning","North East and Yorkshire/Other/Care Home Needs Assessment & Personalised Care and Support Planning","North West/Other/Care Home Needs Assessment & Personalised Care and Support Planning","South East/Other/Care Home Needs Assessment & Personalised Care and Support Planning","South West/Other/Care Home Needs Assessment & Personalised Care and Support Planning","East of England/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","London/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","Midlands/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","North East and Yorkshire/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","North West/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","South East/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","South West/Primary Care Network/Care Home Needs Assessment & Personalised Care and Support Planning","East of England/Extended Access Provision/Care Home Visit","London/Extended Access Provision/Care Home Visit","Midlands/Extended Access Provision/Care Home Visit","North East and Yorkshire/Extended Access Provision/Care Home Visit","South East/Extended Access Provision/Care Home Visit","South West/Extended Access Provision/Care Home Visit","East of England/General Practice/Care Home Visit","London/General Practice/Care Home Visit","Midlands/General Practice/Care Home Visit","North East and Yorkshire/General Practice/Care Home Visit","North West/General Practice/Care Home Visit","South East/General Practice/Care Home Visit","South West/General Practice/Care Home Visit","East of England/Other/ ...

# %% [markdown]
# # No Show Appointment

# %%
# DNA appointments distribution (patient pathway)

# Appointment Distribution [HCP type, Appointment mode, Waiting time, Final Status]
data = ar.groupby(['appointment_month','region','hcp_type','appointment_mode','time_between_book_and_appointment','appointment_status'])['count_of_appointments'].sum().reset_index()
filter = (data['appointment_status']=='DNA') & (data['appointment_month']=='2022-04-01')

fig =px.sunburst(data[filter], 
                 path=['region','hcp_type','appointment_mode'], #'time_between_book_and_appointment'],
                 values='count_of_appointments',
                 title='DNA Appointment Distribution - region, HCP type, appointment mode, Waiting time',
                  width=750, height=750)
fig.update_traces(textinfo="label+percent parent")
fig.show()
# Out:
# <div>                            <div id="fb4d7652-5475-4caa-b967-33e5455e2a13" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb4d7652-5475-4caa-b967-33e5455e2a13")) {                    Plotly.newPlot(                        "fb4d7652-5475-4caa-b967-33e5455e2a13",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_of_appointments=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["East of England/GP/Face-to-Face","London/GP/Face-to-Face","Midlands/GP/Face-to-Face","North East and Yorkshire/GP/Face-to-Face","North West/GP/Face-to-Face","South East/GP/Face-to-Face","South West/GP/Face-to-Face","East of England/Other Practice staff/Face-to-Face","London/Other Practice staff/Face-to-Face","Midlands/Other Practice staff/Face-to-Face","North East and Yorkshire/Other Practice staff/Face-to-Face","North West/Other Practice staff/Face-to-Face","South East/Other Practice staff/Face-to-Face","South West/Other Practice staff/Face-to-Face","East of England/Unknown/Face-to-Face","London/Unknown/Face-to-Face","Midlands/Unknown/Face-to-Face","North East and Yorkshire/Unknown/Face-to-Face","North West/Unknown/Face-to-Face","South East/Unknown/Face-to-Face","South West/Unknown/Face-to-Face","East of England/GP/Home Visit","London/GP/Home Visit","Midlands/GP/Home Visit","North East and Yorkshire/GP/Home Visit","North West/GP/Home Visit","South East/GP/Home Visit","South West/GP/Home Visit","East of England/Other Practice staff/Home Visit","London/Other Practice staff/Home Visit","Midlands/Other Practice staff/Home Visit","North East and Yorkshire/Other Practice staff/Home Visit","North West/Other Practice staff/Home Visit","South East/Other Practice staff/Home Visit","South West/Other Practice staff/Home Visit","East of England/Unknown/Home Visit","London/Unknown/Home Visit","Midlands/Unknown/Home Visit","North East and Yorkshire/Unknown/Home Visit","North West/Unknown/Home Visit","South East/Unknown/Home Visit","South West/Unknown/Home Visit","East of England/GP/Telephone","London/GP/Telephone","Midlands/GP/Telephone","North East and Yorkshire/GP/Telephone","North West/GP/Telephone","South East/GP/Telephone","South West/GP/Telephone","East of England/Other Practice staff/Telephone","London/Other Practice staff/Telephone","Midlands/Other Practice staff/Telephone","North East and Yorkshire/Other Practice staff/Telephone","North West/Other Practice staff/Telephone","South East/Other Practice staff/Telephone","South West/Other Practice staff/Telephone","East of England/Unknown/Telephone","London/Unknown/Telephone","Midlands/Unknown/Telephone","North East and Yorkshire/Unknown/Telephone","North West/Unknown/Telephone","South East/Unknown/Telephone","South West/Unknown/Telephone","East of England/GP/Unknown","London/GP/Unknown","Midlands/GP/Unknown","North East and Yorkshire/GP/Unknown","North West/GP/Unknown","South East/GP/Unknown","South West/GP/Unknown","East of England/Other Practice staff/Unknown","London/Other Practice staff/Unknown","Midlands/Other Practice staff/Unknown","North East and Yorkshire/Other Practice staff/Unknown","North West/Other Practice staff/Unknown","South East/Other Practice staff/Unknown","South West/Other Practice staff/Unknown","East of England/Unknown/Unknown","London/Unknown/Unknown","Midlands/Unknown/Unknown","North East and Yorkshire/Unknown/Unknown","North West/Unknown/Unknown","South East/Unknown/Unknown","South West/Unknown/Unknown","East of England/GP/Video/Online","London/GP/Video/Online","Midlands/GP/Video/Online","North East and Yorkshire/GP/Video/Online","North West/GP/Video/Online","South East/GP/Video/Online","South West/GP/Video/Online","East of England/Other Practice staff/Vid ...

# %%
data = ar[ar['appointment_status'] == 'DNA']
data = data.groupby(['appointment_status','hcp_type','appointment_mode','time_between_book_and_appointment'])['count_of_appointments'].agg('sum').reset_index()

fig = px.bar(data, x='appointment_mode', y='count_of_appointments',color='time_between_book_and_appointment',
             facet_col ='hcp_type',facet_row ='appointment_status',
             category_orders={'time_between_book_and_appointment': 
                              ['Same Day','1 Day', '2 to 7 Days','8  to 14 Days','15  to 21 Days', 
                               '22  to 28 Days', 'More than 28 Days','Unknown / Data Quality']},
             title="DNA Appointments", template='none')   
fig.update_layout(barmode="relative")
fig.show()
# Out:
# <div>                            <div id="ea624215-03fb-48e6-ba91-0710f8591492" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea624215-03fb-48e6-ba91-0710f8591492")) {                    Plotly.newPlot(                        "ea624215-03fb-48e6-ba91-0710f8591492",                        [{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=Same Day<br>appointment_status=DNA<br>hcp_type=GP<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Same Day","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Same Day","offsetgroup":"Same Day","orientation":"v","showlegend":true,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x","y":[1626228,30292,1438851,116074,11189],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=Same Day<br>appointment_status=DNA<br>hcp_type=Other Practice staff<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Same Day","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Same Day","offsetgroup":"Same Day","orientation":"v","showlegend":false,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x2","y":[1588996,22438,798925,196050,13576],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=Same Day<br>appointment_status=DNA<br>hcp_type=Unknown<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"Same Day","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"Same Day","offsetgroup":"Same Day","orientation":"v","showlegend":false,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x3","y":[30107,39592,85708,54440,138],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=1 Day<br>appointment_status=DNA<br>hcp_type=GP<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"1 Day","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"1 Day","offsetgroup":"1 Day","orientation":"v","showlegend":true,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x","y":[614953,6907,335504,22791,4995],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=1 Day<br>appointment_status=DNA<br>hcp_type=Other Practice staff<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"1 Day","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"1 Day","offsetgroup":"1 Day","orientation":"v","showlegend":false,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x2","y":[1213840,9255,267439,65238,11840],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=1 Day<br>appointment_status=DNA<br>hcp_type=Unknown<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"1 Day","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"1 Day","offsetgroup":"1 Day","orientation":"v","showlegend":false,"textposition":"auto","x":["Face-to-Face","Home Visit","Telephone","Unknown","Video/Online"],"xaxis":"x3","y":[16603,15562,17199,32403,7],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"time_between_book_and_appointment=2 to 7 Days<br>appointment_status=DNA<br>hcp_type=GP<br>appointment_mode=%{x}<br>count_of_appointments=%{y}<extra></extra>","legendgroup":"2 to 7 Days","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"2 to 7 Days","offsetgroup":"2 to 7 ...

# %%
# Tree plot
# Determine the trend of DNA appintment.
ar_filter = (ar['appointment_status'] == "DNA")

# View the output.
filtered_ar = ar.loc[ar_filter]

ar_tree = filtered_ar.groupby(['hcp_type','appointment_mode','time_between_book_and_appointment'])['count_of_appointments'].sum().reset_index()

ar_tree["all"] = "all" # in order to have a single root node
fig = px.treemap(ar_tree, 
                 path=['all','hcp_type','appointment_mode','time_between_book_and_appointment'], 
                 values='count_of_appointments', title="DNA appointments per month, appointment mode, waiting time") # 面积大小用total_bill字段决定
                
fig.update_traces(textinfo="label+percent parent")
fig.show()
# Out:
# <div>                            <div id="dce66bf8-95be-4b7d-b689-be5045109498" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dce66bf8-95be-4b7d-b689-be5045109498")) {                    Plotly.newPlot(                        "dce66bf8-95be-4b7d-b689-be5045109498",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_of_appointments=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["all/GP/Face-to-Face/1 Day","all/Other Practice staff/Face-to-Face/1 Day","all/Unknown/Face-to-Face/1 Day","all/GP/Home Visit/1 Day","all/Other Practice staff/Home Visit/1 Day","all/Unknown/Home Visit/1 Day","all/GP/Telephone/1 Day","all/Other Practice staff/Telephone/1 Day","all/Unknown/Telephone/1 Day","all/GP/Unknown/1 Day","all/Other Practice staff/Unknown/1 Day","all/Unknown/Unknown/1 Day","all/GP/Video/Online/1 Day","all/Other Practice staff/Video/Online/1 Day","all/Unknown/Video/Online/1 Day","all/GP/Face-to-Face/15  to 21 Days","all/Other Practice staff/Face-to-Face/15  to 21 Days","all/Unknown/Face-to-Face/15  to 21 Days","all/GP/Home Visit/15  to 21 Days","all/Other Practice staff/Home Visit/15  to 21 Days","all/Unknown/Home Visit/15  to 21 Days","all/GP/Telephone/15  to 21 Days","all/Other Practice staff/Telephone/15  to 21 Days","all/Unknown/Telephone/15  to 21 Days","all/GP/Unknown/15  to 21 Days","all/Other Practice staff/Unknown/15  to 21 Days","all/Unknown/Unknown/15  to 21 Days","all/GP/Video/Online/15  to 21 Days","all/Other Practice staff/Video/Online/15  to 21 Days","all/Unknown/Video/Online/15  to 21 Days","all/GP/Face-to-Face/2 to 7 Days","all/Other Practice staff/Face-to-Face/2 to 7 Days","all/Unknown/Face-to-Face/2 to 7 Days","all/GP/Home Visit/2 to 7 Days","all/Other Practice staff/Home Visit/2 to 7 Days","all/Unknown/Home Visit/2 to 7 Days","all/GP/Telephone/2 to 7 Days","all/Other Practice staff/Telephone/2 to 7 Days","all/Unknown/Telephone/2 to 7 Days","all/GP/Unknown/2 to 7 Days","all/Other Practice staff/Unknown/2 to 7 Days","all/Unknown/Unknown/2 to 7 Days","all/GP/Video/Online/2 to 7 Days","all/Other Practice staff/Video/Online/2 to 7 Days","all/Unknown/Video/Online/2 to 7 Days","all/GP/Face-to-Face/22  to 28 Days","all/Other Practice staff/Face-to-Face/22  to 28 Days","all/Unknown/Face-to-Face/22  to 28 Days","all/GP/Home Visit/22  to 28 Days","all/Other Practice staff/Home Visit/22  to 28 Days","all/Unknown/Home Visit/22  to 28 Days","all/GP/Telephone/22  to 28 Days","all/Other Practice staff/Telephone/22  to 28 Days","all/Unknown/Telephone/22  to 28 Days","all/GP/Unknown/22  to 28 Days","all/Other Practice staff/Unknown/22  to 28 Days","all/Unknown/Unknown/22  to 28 Days","all/GP/Video/Online/22  to 28 Days","all/Other Practice staff/Video/Online/22  to 28 Days","all/Unknown/Video/Online/22  to 28 Days","all/GP/Face-to-Face/8  to 14 Days","all/Other Practice staff/Face-to-Face/8  to 14 Days","all/Unknown/Face-to-Face/8  to 14 Days","all/GP/Home Visit/8  to 14 Days","all/Other Practice staff/Home Visit/8  to 14 Days","all/Unknown/Home Visit/8  to 14 Days","all/GP/Telephone/8  to 14 Days","all/Other Practice staff/Telephone/8  to 14 Days","all/Unknown/Telephone/8  to 14 Days","all/GP/Unknown/8  to 14 Days","all/Other Practice staff/Unknown/8  to 14 Days","all/Unknown/Unknown/8  to 14 Days","all/GP/Video/Online/8  to 14 Days","all/Other Practice staff/Video/Online/8  to 14 Days","all/Unknown/Video/Online/8  to 14 Days","all/GP/Face-to-Face/More than 28 Days","all/Other Practice staff/Face-to-Face/More than 28 Days","all/Unknown/Face-to-Face/More than 28 Days","all/GP/Home Visit/More than 28 Days","all/Other Practice staff/Home Visit/More than 28 Days","all/Unknown/Home Visit/More than 28 Days" ...

# %%
# DNA Appointment Distribution [HCP type, Appointment mode, Waiting time, Final Status]

data = ar.groupby(['hcp_type','appointment_mode','time_between_book_and_appointment','appointment_status'])['count_of_appointments'].sum().reset_index()
filter = data['appointment_status']=='DNA'

fig =px.sunburst(data[filter], 
                 path=['hcp_type','appointment_mode','time_between_book_and_appointment'],
                 values='count_of_appointments',
                       title='DNA Appointment Distribution - region, HCP type, appointment mode, Waiting time',
                  width=750, height=750,template = 'none')
fig.update_traces(textinfo="label+percent parent")
fig.show()
# Out:
# <div>                            <div id="1622ecc0-52af-4142-b635-9013cace35e7" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1622ecc0-52af-4142-b635-9013cace35e7")) {                    Plotly.newPlot(                        "1622ecc0-52af-4142-b635-9013cace35e7",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count_of_appointments=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["GP/Face-to-Face/1 Day","Other Practice staff/Face-to-Face/1 Day","Unknown/Face-to-Face/1 Day","GP/Home Visit/1 Day","Other Practice staff/Home Visit/1 Day","Unknown/Home Visit/1 Day","GP/Telephone/1 Day","Other Practice staff/Telephone/1 Day","Unknown/Telephone/1 Day","GP/Unknown/1 Day","Other Practice staff/Unknown/1 Day","Unknown/Unknown/1 Day","GP/Video/Online/1 Day","Other Practice staff/Video/Online/1 Day","Unknown/Video/Online/1 Day","GP/Face-to-Face/15  to 21 Days","Other Practice staff/Face-to-Face/15  to 21 Days","Unknown/Face-to-Face/15  to 21 Days","GP/Home Visit/15  to 21 Days","Other Practice staff/Home Visit/15  to 21 Days","Unknown/Home Visit/15  to 21 Days","GP/Telephone/15  to 21 Days","Other Practice staff/Telephone/15  to 21 Days","Unknown/Telephone/15  to 21 Days","GP/Unknown/15  to 21 Days","Other Practice staff/Unknown/15  to 21 Days","Unknown/Unknown/15  to 21 Days","GP/Video/Online/15  to 21 Days","Other Practice staff/Video/Online/15  to 21 Days","Unknown/Video/Online/15  to 21 Days","GP/Face-to-Face/2 to 7 Days","Other Practice staff/Face-to-Face/2 to 7 Days","Unknown/Face-to-Face/2 to 7 Days","GP/Home Visit/2 to 7 Days","Other Practice staff/Home Visit/2 to 7 Days","Unknown/Home Visit/2 to 7 Days","GP/Telephone/2 to 7 Days","Other Practice staff/Telephone/2 to 7 Days","Unknown/Telephone/2 to 7 Days","GP/Unknown/2 to 7 Days","Other Practice staff/Unknown/2 to 7 Days","Unknown/Unknown/2 to 7 Days","GP/Video/Online/2 to 7 Days","Other Practice staff/Video/Online/2 to 7 Days","Unknown/Video/Online/2 to 7 Days","GP/Face-to-Face/22  to 28 Days","Other Practice staff/Face-to-Face/22  to 28 Days","Unknown/Face-to-Face/22  to 28 Days","GP/Home Visit/22  to 28 Days","Other Practice staff/Home Visit/22  to 28 Days","Unknown/Home Visit/22  to 28 Days","GP/Telephone/22  to 28 Days","Other Practice staff/Telephone/22  to 28 Days","Unknown/Telephone/22  to 28 Days","GP/Unknown/22  to 28 Days","Other Practice staff/Unknown/22  to 28 Days","Unknown/Unknown/22  to 28 Days","GP/Video/Online/22  to 28 Days","Other Practice staff/Video/Online/22  to 28 Days","Unknown/Video/Online/22  to 28 Days","GP/Face-to-Face/8  to 14 Days","Other Practice staff/Face-to-Face/8  to 14 Days","Unknown/Face-to-Face/8  to 14 Days","GP/Home Visit/8  to 14 Days","Other Practice staff/Home Visit/8  to 14 Days","Unknown/Home Visit/8  to 14 Days","GP/Telephone/8  to 14 Days","Other Practice staff/Telephone/8  to 14 Days","Unknown/Telephone/8  to 14 Days","GP/Unknown/8  to 14 Days","Other Practice staff/Unknown/8  to 14 Days","Unknown/Unknown/8  to 14 Days","GP/Video/Online/8  to 14 Days","Other Practice staff/Video/Online/8  to 14 Days","Unknown/Video/Online/8  to 14 Days","GP/Face-to-Face/More than 28 Days","Other Practice staff/Face-to-Face/More than 28 Days","Unknown/Face-to-Face/More than 28 Days","GP/Home Visit/More than 28 Days","Other Practice staff/Home Visit/More than 28 Days","Unknown/Home Visit/More than 28 Days","GP/Telephone/More than 28 Days","Other Practice staff/Telephone/More than 28 Days","Unknown/Telephone/More than 28 Days","GP/Unknown/More than 28 Days","Other Practice staff/Unknown/More than 28 Days","Unknown/Unknown/More than 28 Days","GP/Video/Online/More than 28 Days","Other Practice staff/Video/Online/More than 28  ...
